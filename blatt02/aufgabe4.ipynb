# %% [markdown]
# # Implementierung des Gauss Algorithmus

# %% [markdown]
# ## Inputs and Config:

# %%
def matrix_product(a,b):
    # a and b are nxn matrices (and an array of columns)
    b = []
    for i in range(0, len(a)):
        b.append([])
        for j in range (0, len(a)):
            b[i][j] += a[j][i] * b[i][j]
    return b

# %%
DOING_PIVOT = True

n = 3

a = [[1,-2,3],[3,-5,7],[-2,2,-7]] #the matrix is an array of columns

b = [2,-3,9]

l = [[1,0,0],[0,1,0],[0,0,1]]

p = []

# %% [markdown]
# ## 1. Step: Berechnung der Matrizen P,L,R

# %%
# loop through every column (every inner array)
# change to for in range loop
for i in range(0,n-1):
    # we are inside column i
    column = a[i]
    pivot_value = column[i]
    pivot_position = i
    for j in range(i+1, n):
        if abs(column[j]) > abs(pivot_value):
            # if we have a bigger element change the pivot element and position
            pivot_value = column[j]
            pivot_position = j
    if (pivot_position != i):
        # if we have found a new pivot element switch the current row with the new pivot row
        print("changed pivot element")
        a = matrix_product(p,a)
        
    # after we changed the necessary rows and updated our p we can calculate the elimination matrix
    for k in range(i, n):
        l[i][k] = column[k] / column[i]

    # after we have caluclated the elimination matrix we can calculate the next a
    a = matrix_product(l,a)

r = a
# Out:
# changed pivot element
# 0
# 0
# 0
# 1
# 0
# 2
# changed pivot element
# 1
# 1
# 1
# 2

# %% [markdown]
# ## 2. Loesen des Systems Lc = Pb

# %% [markdown]
# ## 3. Loesen des Systems Rx = b
